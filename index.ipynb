# %%
import numpy as np

# %%
import pandas as pd

# %%
# latency before index

# %%
data = {'threads': [1, 10, 100, 1000], 'latency': [270.09, 1050, 1440, 1530]}

# %%
df = pd.DataFrame(data=data)

# %%
df.plot(x='threads', y='latency')
# Out:
# <AxesSubplot:xlabel='threads'>

# %%
# throughput before index

# %%
data = {'threads': [1, 10, 100, 1000], 'throughput': [3.62, 15.40, 10.58, 8.37]}

# %%
df = pd.DataFrame(data=data)

# %%
df.plot(x='threads', y='throughput')
# Out:
# <AxesSubplot:xlabel='threads'>

# %%
# latency after index

# %%
data = {'threads': [1, 10, 100, 1000], 'latency': [7.24, 23.45, 236.92, 1200]}

# %%
df = pd.DataFrame(data=data)

# %%
df.plot(x='threads', y='latency')
# Out:
# <AxesSubplot:xlabel='threads'>

# %%
# throughput after index

# %%
data = {'threads': [1, 10, 100, 1000], 'throughput': [139.15, 429.99, 418.91, 433.32]}

# %%
df = pd.DataFrame(data=data)

# %%
df.plot(x='threads', y='throughput')
# Out:
# <AxesSubplot:xlabel='threads'>
